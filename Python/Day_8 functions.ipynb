# %%
print("hello world")
# Out:
# hello world

# %%
# addition of 2 element - normal code

# %%
a = 10
b = 20
total = a + b 
print(total)
# Out:
# 30

# %%
greet = "Good afternoon all"

# %%
def function_name(paramerters):
    print

# %%
def greet():
    print("Good morning,: ")

# %%
def greet(student_name):
    print("Good afternoon" , student_name)

# %%
greet("Rock")
# Out:
# Good afternoon and have a nice day Rock
# good night

# %%
greet("Rahul")
# Out:
# Good afternoon and have a nice day Rahul

# %%
# Function for addition of two elements : 
def add(a , b):
    print("value of a is " , a)
    print("value of b is " , b)

# %%
add(100, 40)
# Out:
# value of a is  100
# value of b is  40

# %%
def add(y , z):
    print(y + z )

# %%
add(10000, 30)
# Out:
# 10030

# %%
# write a function for 3 element. 
def add_of_three(a, b , c):
    print(a + b + c )

# %%
# multiply the 2 elements 
def multiply(a, b ):
    print( a * b )

# %%
multiply(10, 30 )
# Out:
# 300

# %%
x = 100
z = 200

# %%
multiply(x , z)
# Out:
# 20000

# %%
def add(a , b):
    print(a + b )

# %%
result = add(10 , 20)
# Out:
# 30

# %%
print(result)
# Out:
# None

# %%
a = 30

# %%
print(a)
# Out:
# 30

# %%
def add(a , b):
    return a + b

# %%
result = add(10 , 20)
# Out:
# summation of two elements

# %%
# write a function for 2 elemeents and store in result
def multiply(a,  b):
    return a * b 

result = multiply(10 , 20)

# %%
# write a fnction for odd and even
def check_num(num):

    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"

# %%
check_num(10)
# Out:
# 'Even'

# %%
# percentage
marks = [66,77,88,99,100]

# %%
def percentage(marks):
    return sum(marks) / len(marks)

# %%
percentage(marks)
# Out:
# 86.0

# %%
a = [1,2,2,3,4,5,34,23,4,5,43]
sum(a)
# Out:
# 126

# %%
len(a)
# Out:
# 11

# %%
126 / 11
# Out:
# 11.454545454545455

# %%
def percentage(marks):
    return sum(marks) / len(marks)

# %%
cart = [] 
len(cart)
# Out:
# 0

# %%
def blinkit_bill(cart):

    if len(cart) == 0:
        return "Add values in cart"
    return sum(cart) / len(cart)

# %% [markdown]
# # Write any function for list to append
# # write a function to sort the list
# # write a functoin for to check if data contains duplicate of not

# %%
[1,2,2,3] - True 
[1,2,3,4] - False

# %%
blinkit_bill(cart)
# Out:
# 'Add values in cart'

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero
