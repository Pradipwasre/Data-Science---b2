# %%
# break
# continue 
# pass

# %%
print("hello")
# Out:
# hello

# %%
marks = 30

if marks >= 35:
    print("you pass the test")

else:
    print("you failed the test")
# Out:
# you failed the test

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in marks:
    
    break
    print(i)

# %%
marks = [45,3,46,65,34,23,45]

# %%
mark = 34

if mark < 35:
    print("Failed")
# Out:
# Failed

# %%
marks = [45,56,78,52,57,78,1,4]

# %%
for i in marks:
    if i < 35:
        print(i , "you failed you need a feedback")
        break
    print(i)
# Out:
# 45
# 56
# 78
# 52
# 57
# 78
# 1 you failed you need a feedback

# %%
cart = ["spinach" , "tomato" , "avacado" , "drinks"]

# %%
for i in cart:
    if i == "avacado":
        print("we found " , i)
        break
    print(i)
# Out:
# spinach
# tomato
# we found  avacado

# %%
marks = [45,68,36,40,51,100] - if & else
Fail found i
Pass : i

# %%
for i in marks:
    if i >= 35:
        print("Pass" , i)
    else:
        print("Fail found" , i)
        break
# Out:
# Pass 45
# Pass 56
# Pass 78
# Pass 52
# Pass 57
# Pass 78
# Fail found 1

# %%
apps = ["blinkit" , "zepto" ,"zomato" , "swiggy" , "flipkart" ]

# %%
for app in apps:
    print("checking app " , app)
    if app == "zomato":
        print(app , "App Found")
        break
# Out:
# checking app  blinkit
# checking app  zepto
# checking app  zomato
# zomato App Found

# %%
snacks = ["chips" , "taco" , "burger" , "ban maska" , "oats" , "Softy"]

# %%
for i in snacks:
    if i == "oats":
        print("skip it please" , i)
        continue
    print("Yummy eating!" , i)
    print("its sunny day")
    print("it is friday")
# Out:
# Yummy eating! chips
# its sunny day
# it is friday
# Yummy eating! taco
# its sunny day
# it is friday
# Yummy eating! burger
# its sunny day
# it is friday
# Yummy eating! ban maska
# its sunny day
# it is friday
# skip it please oats
# Yummy eating! Softy
# its sunny day
# it is friday

# %%
# Funny continue example with pets
pets = ["dog", "cat", "snake", "parrot"]

for pet in pets:
    if pet == "snake":
        print("Nope! Skip the scary:", pet)
        continue
    print("I like this pet:", pet)
# Out:
# I like this pet: dog
# I like this pet: cat
# Nope! Skip the scary: snake
# I like this pet: parrot

# %%
# Marks list with continue
marks = [85, 30, 75, 40, 25, 90]

for score in marks:
    if score < 40:   # skip failed marks
        print("Skipping fail:", score)
        continue
    print("Pass:", score)
# Out:
# Pass: 85
# Skipping fail: 30
# Pass: 75
# Pass: 40
# Skipping fail: 25
# Pass: 90

# %%
marks = [78,65,85,67,56,100,87]

# %%
for i in marks:
    if i < 90:
        print("you are getting Books" , i)
    else:
        pass
# Out:
# you are getting Books 78
# you are getting Books 65
# you are getting Books 85
# you are getting Books 67
# you are getting Books 56
# you are getting Books 87

# %%
for i in marks:
    if i < 90:
        print("you are getting Books" , i)
    else:
        pass

# %%
nums = [1,2,3,4,5]

for i in nums:
    if i == 3:
        pass
    else:
        print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
nums = [1,2,3,4,5]

for i in nums:
    if i == 3:
        pass
    else:
        print(i)

# %%
marks = [85, 30, 75, 40, 25, 90]

for i in marks:
    if i < 40:
        pass 
    else:
        print("you pass exam" , i)
# Out:
# you pass exam 85
# you pass exam 75
# you pass exam 40
# you pass exam 90

# %%
apps = ["blinkit" , "zepto" ,"zomato" , "swiggy" , "flipkart" ]

# %%
search = input()

# %%
search = input()
for i in apps:
    print("checking app " , i)
    if i == search:
        print("Found APP" , i)
        break
# Out:
# checking app  blinkit
# checking app  zepto
# checking app  zomato
# Found APP zomato
