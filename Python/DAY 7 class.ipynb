# %%
print("hello world")
# Out:
# hello world

# %%
a = {"rock" , "john", "rock"}
a
# Out:
# {'john', 'rock'}

# %%
a = []
a = ()
a=  set()
a = {}

# %%
student = {"Name" : "Rock", "Name" : "John"}

# %%
name = "rock"
name = "john"

# %%
student
# Out:
# {'Name': 'John'}

# %%
# create a dict
student = {"Name" : "Rock" , "class" : 10 , "city" : "pune" , "marks":[88,99,100]}

# %%
print(student)
# Out:
# {'Name': 'Rock', 'class': 10, 'city': 'pune', 'marks': [88, 99, 100]}

# %%
student.keys()
# Out:
# dict_keys(['Name', 'class', 'city', 'marks'])

# %%
student.values()
# Out:
# dict_values(['Rock', 10, 'pune', [88, 99, 100]])

# %%
student.items()
# Out:
# dict_items([('Name', 'Rock'), ('class', 10), ('city', 'pune'), ('marks', [88, 99, 100])])

# %%
student = {"Name" : "Virat" , 
           "Class" : 10 , 
           "marks" : [77,88,99,100,100,88],
           "city" : "pune" , 
           "sports" : "Cricket"}

# %%
student.items()
# Out:
# dict_items([('Name', 'Virat'), ('Class', 10), ('marks', [77, 88, 99, 100, 100, 88]), ('city', 'pune'), ('sports', 'Cricket')])

# %%
for key , values in student.items():
    print(key , "->" , values)
# Out:
# Name -> Virat
# Class -> 10
# marks -> [77, 88, 99, 100, 100, 88]
# city -> pune
# sports -> Cricket

# %%
student["marks"]
# Out:
# [77, 88, 99, 100, 100, 88]

# %%
student['id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 student['id']
#
# KeyError: 'id'

# %%
# for loop 
for k , v in student.items():
    print( k , v )
# Out:
# Name Virat
# Class 10
# marks [77, 88, 99, 100, 100, 88]
# city pune
# sports Cricket

# %%
student.get("Name" , "Unknown name key")
# Out:
# 'Virat'

# %%
student.update({"ID" : 1})

# %%
student.update({"Gender": "Male" , "Division" : "A"})

# %%
student.update({"marks": [88,99,89,89,99] })

# %%
for k , v in student.items():
    print(k , ": ", v)
# Out:
# Name :  Rohit
# Class :  10
# marks :  [88, 99, 89, 89, 99]
# city :  pune
# sports :  Cricket
# ID :  1
# Gender :  Male
# Division :  A
# Marks :  [88, 99, 89, 89, 99]

# %%
# key 
# value
# items 
# get
# update
# pop
# clear

# %%
student.pop("Marks")
# Out:
# [88, 99, 89, 89, 99]

# %%
for k , v in student.items():
    print(k , v )
# Out:
# Name Rohit
# Class 10
# marks [88, 99, 89, 89, 99]
# city pune
# sports Cricket
# ID 1
# Gender Male
# Division A

# %%
student.pop("city")
# Out:
# 'pune'

# %%
student.items()
# Out:
# dict_items([('Name', 'Rohit'), ('Class', 10), ('marks', [88, 99, 89, 89, 99]), ('sports', 'Cricket'), ('ID', 1), ('Gender', 'Male'), ('Division', 'A')])

# %%
student.clear()

# %%
student.items()
# Out:
# dict_items([])

# %%
a = {"food" : "oats" , "drink" : "Coffee"}

# %%
b = a.copy()

# %%
for k , v in b.items():
    print(k , ":",v)
# Out:
# food : oats
# drink : Coffee

# %%
for k ,v in Marks.items():
    if v > 50:
        print( k , v )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 for k ,v in Marks.items():
#       2     if v > 50:
#       3         print( k , v )
#
# NameError: name 'Marks' is not defined
