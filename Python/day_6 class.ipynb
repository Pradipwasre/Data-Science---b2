# %%
structures = """
    1. list = a = [1,2,4],
    2. tuple = a = (1,2,3)
    3. set = a = {1,2,3}
"""

# %%
a = ["pune" , "mumbai" , 'pune' , "blr" , 'kochin' , 'pune'] # list
b = ("pune" , "mumbai" , 'pune' , "blr" , 'kohin' , 'pune') # tuple
c = {"pune" , "mumbai" , 'pune ', 'kochin' , 'pune'} # set

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'set'>

# %%
print(a)
print(b)
print(c)
# Out:
# ['pune', 'mumbai', 'pune', 'blr', 'kochin', 'pune']
# ('pune', 'mumbai', 'pune', 'blr', 'kohin', 'pune')
# {'pune ', 'mumbai', 'pune', 'kochin'}

# %%
cart = {"milk" , 'bread' , 'cokkies' , 'milk','rice'}

# %%
cart
# Out:
# {'bread', 'cokkies', 'milk', 'rice'}

# %%
cart = ("milk" , 'bread' , 'cokkies' , 'milk','rice')
print(cart)
# Out:
# ('milk', 'bread', 'cokkies', 'milk', 'rice')

# %%
# list & tuple = allow duplicates
# set = do not allow duplicate

# %%
# methods list and tuple
# .add()

# %%
cart = {"rice"}

# %%
a = [1,2,3]
a.append(10)
print(a)
# Out:
# [1, 2, 3, 10]

# %%
cart.add("water")

# %%
print(cart)
# Out:
# {'rice', 'water'}

# %%
cart.add("masala")

# %%
cart
# Out:
# {'masala', 'rice', 'water'}

# %%
cart.add("bowl")

# %%
cart
# Out:
# {'bowl', 'masala', 'rice', 'water'}

# %%
# create set for the cities : use .add()

# %%
city = set()

# %%
print(city)
# Out:
# set()

# %%
city.add("mumbai")
city.add("pune")

# %%
city
# Out:
# {'mumbai', 'pune'}

# %%
record = ["rahul" , "rahul" , "raj" , "rock" , "dwen" , "rahul" , "virat" , "rohit"]
print(record)
# Out:
# ['rahul', 'rahul', 'raj', 'rock', 'dwen', 'rahul', 'virat', 'rohit']

# %%
p = set()

# %%
for i in record:
    p.add(i)

# %%
p
# Out:
# {'dwen', 'rahul', 'raj', 'rock', 'rohit', 'virat'}

# %%
a= {1,2,3,4,5}

# %%
a.add(100)

# %%
a
# Out:
# {1, 2, 3, 4, 5, 100}

# %%
a.add(11)

# %%
a
# Out:
# {1, 2, 3, 4, 5, 11, 100}

# %%
# extent
a = {1,2,3}
b =[44,55,66]

# %%
a.update(b)

# %%
a
# Out:
# {1, 2, 3, 44, 55, 66}

# %%
fruits = {"apple" , "jack fruit"}

# %%
fruits.update(["oranges" , "mangoes", "kiwi","oranges"])

# %%
fruits
# Out:
# {'apple', 'jack fruit', 'kiwi', 'mangoes', 'oranges'}

# %%
# add 
# update
# remove

# %%
print(fruits)
# Out:
# {'oranges', 'apple', 'kiwi', 'jack fruit', 'mangoes'}

# %%
fruits.remove("apple")

# %%
fruits
# Out:
# {'jack fruit', 'kiwi', 'mangoes', 'oranges'}

# %%
fruits.remove("banana")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 fruits.remove("banana")
#
# KeyError: 'banana'

# %%
fruits.discard("banana")

# %%
# .remove = the item should present , if no : then error
# .dicard = no matter item is present of not : if present it remove

# %%
products = {"board" , "screen" , "code"}

# %%
products.remove("laptop") # so we can use the discard to prevent the 'Key Error'.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 products.remove("laptop")
#
# KeyError: 'laptop'

# %%
# .add : adding the item
# .update : adding the multiple items in one go
# .remove : removing the items
# .discard : remove the items, if item not present , does not produce any error
# .pop : rendomly remove item

# %%
lottery = {"rock" , "john cena" , "big show" , "mark hannery", "goldi" , "brock"}

# %%
lottery.pop()
# Out:
# 'john cena'

# %%
lottery
# Out:
# {'big show', 'brock', 'goldi', 'rock'}

# %%
# .add - adding single element
# .update - updating multiple elements 
# .remove - removing single element, if not present thorws error
# .discard - removeing single element, if not present does not throws error
# .pop - randomly remove elelent
# .clear - claer the set items 
# .copy - copy the data

# %%
lottery
# Out:
# {'big show', 'brock', 'goldi', 'rock'}

# %%
lottery.clear()

# %%
lottery
# Out:
# set()

# %%
a = {"mango" , "kiwi"}

# %%
new_set = a.copy() # method

print(new_set)
# Out:
# {'kiwi', 'mango'}

# %%
print(a)
print(new_set)
# Out:
# {'kiwi', 'mango'}
# {'kiwi', 'mango'}

# %%
a.remove('mango')

# %%
print(a)
print(new_set)
# Out:
# {'kiwi'}
# {'kiwi', 'mango'}

# %%
# add()
# update()
# remove()
# discard()
# clear() 
# pop()
# copy()

# %%
# print set elements
fruis = {"apple" , "banana" , "cherry"} # use for loop to pring each elements

# %%
# print squres from set
nums = {2,4,6,8}

# %%
# check membership
members = {"amit" , "sneha" , "rahul"} # use a for loop to check if "sneha" is present

# %%
a = {1,2,3,4,5,6,7,5}

# %%
# count elements
elements = {1,2,3,4,5} # use a for loop and no use of len()
